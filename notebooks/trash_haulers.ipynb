# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
hauler = pd.read_csv('../data/trash_hauler_report.csv')

# %%
hauler.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 0   37207.0    RED RIVER        3205               2.0  1.727970e+06
# 1   37218.0    RED RIVER        4202               1.0  1.721259e+06
# 2   37209.0    RED RIVER        4205              20.0  1.707027e+06
# 3   37207.0    WASTE IND        2206               2.0  1.735692e+06
# 4   37209.0    RED RIVER        4203              20.0  1.710186e+06
#
#     State Plan Y
# 0  686779.478089
# 1  685444.799565
# 2  659887.471571
# 3  685027.245923
# 4  664205.101066

# %%
hauler.shape
# Out:
# (20226, 11)

# %%
hauler.tail()
# Out:
#        Request Number Date Opened                              Request   \
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 20221                             2731 Murfreesboro Pike   37013.0
# 20222  1621 Long Ave, Nashville, TN 37206, United States   37206.0
# 20223  2943 Windemere Cir, Nashville, TN 37214, Unite...   37214.0
# 20224  3325 Murfreesboro Pike, Nashville, TN 37013, U...   37013.0
# 20225  604 Somerset Ct, Nashville, TN 37217, United S...   37217.0
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y
# 20221    RED RIVER        4502              32.0  1.781137e+06  632448.551144
# 20222        METRO        9508               6.0  1.749711e+06  669201.601569
# 20223    RED RIVER        1502              15.0  1.770293e+06  674936.303809
# 20224    RED RIVER        4502              32.0  1.785225e+06  627146.400187
# 20225    RED RIVER        2505              29.0  1.781360e+06  637742.006846

# %%
zip_counts = hauler['Zip Code'].value_counts()
print(zip_counts)
# Out:
# Zip Code
# 37013.0    2278
# 37211.0    2248
# 37205.0    1491
# 37209.0    1411
# 37215.0    1404
# 37207.0    1300
# 37115.0    1266
# 37206.0    1217
# 37208.0    1039
# 37214.0    1004
# 37218.0     983
# 37216.0     841
# 37217.0     832
# 37204.0     635
# 37212.0     601
# 37210.0     550
# 37203.0     394
# 37220.0     289
# 37027.0     168
# 37189.0      60
# 37221.0      48
# 37219.0      42
# 37201.0      35
# 37076.0       5
# 37138.0       5
# 37086.0       3
# 37213.0       1
# 37228.0       1
# Name: count, dtype: int64

# %%
hauler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.7+ MB

# %% [raw]
# hauler.rename(columns={'Request ': 'Complaint'}, inplace=True)

# %%
hauler[ 'Request '] = hauler[ 'Request '].astype('string')

# %%
hauler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  string
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(5), string(1)
# memory usage: 1.7+ MB

# %%
#hauler_filtered = hauler.loc[hauler['Trash Hauler'].str.contains('RED RIVER') == True]
#hauler_filtered

# %%
hauler['Description'] = hauler['Description'].fillna("").str.lower().astype('string')
hauler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  string
#  3   Description       20226 non-null  string
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(4), string(2)
# memory usage: 1.7+ MB

# %%
#missed_and_hauler = hauler_filtered.loc[hauler_filtered['Request '].str.contains('Missed') == True]
#missed_and_hauler

# %%
#missed_pickups = hauler[hauler['Request '].str.contains('Missed') & hauler['Description'].str.contains('(?i)missed')]
#missed_pickups

# %%
missed_pickups = hauler.loc[hauler['Request '].str.contains('(?i)Missed') | hauler['Description'].str.contains('(?i)miss')]
missed_pickups
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 7               25327    11/01/17            Trash Collection Complaint
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 1                               curb/trash miss tuesday.
# 2                               curb/trash miss tuesday.
# 3                                                 missed
# 4                      missed the even side of the road.
# 7           trash out on time, miss again tuesday. alley
# ...                                                  ...
# 20221                          missed...neighbors missed
# 20222                                       entire alley
# 20223                                     missed several
# 20224  caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 1                                  4028 Clarksville Pike   37218.0
# 2                                    6528 Thunderbird Dr   37209.0
# 3                                   2603 old matthews rd   37207.0
# 4                                          604 croley dr   37209.0
# 7                                   1816 Jo Johnston Ave   37203.0
# ...                                                  ...       ...
# 20221                             2731 Murfreesboro Pike   37013.0
# 20222  1621 Long Ave, Nashville, TN 37206, United States   37206.0
# 20223  2943 Windemere Cir, Nashville, TN 37214, Unite...   37214.0
# 20224  3325 Murfreesboro Pike, Nashville, TN 37013, U...   37013.0
# 20225  604 Somerset Ct, Nashville, TN 37217, United S...   37217.0
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y
# 1        RED RIVER        4202               1.0  1.721259e+06  685444.799565
# 2        RED RIVER        4205              20.0  1.707027e+06  659887.471571
# 3        WASTE IND        2206               2.0  1.735692e+06  685027.245923
# 4        RED RIVER        4203              20.0  1.710186e+06  664205.101066
# 7            METRO        9208              21.0  1.731459e+06  666013.601229
# ...            ...         ...               ...           ...            ...
# 20221    RED RIVER        4502              32.0  1.781137e+06  632448.551144
# 20222        METRO        9508               6.0  1.749711e+06  669201.601569
# 20223    RED RIVER        1502              15.0  1.770293e+06  674936.303809
# 20224    RED RIVER        4502              32.0  1.785225e+06  627146.400187
# 20225    RED RIVER        2505              29.0  1.781360e+06  637742.006846
#
# [17739 rows x 11 columns]

# %%
#bellshauler = hauler.loc[
#    (hauler['Description'].str.contains('miss') == True) |
#    (hauler['Request '].str.contains('Missed') == True)]
#bellshauler

# %%
redmiss =  missed_pickups.loc[missed_pickups['Trash Hauler'].str.contains('RED RIVER') == True]
redmiss
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 8               25330    11/01/17  Trash - Curbside/Alley Missed Pickup
# 10              25341    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20220          267121    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 1                               curb/trash miss tuesday.
# 2                               curb/trash miss tuesday.
# 4                      missed the even side of the road.
# 8                                                missed.
# 10     missed trash pickup - resident has at curb for...
# ...                                                  ...
# 20220                                             missed
# 20221                          missed...neighbors missed
# 20223                                     missed several
# 20224  caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address  Zip Code  \
# 1                                  4028 Clarksville Pike   37218.0
# 2                                    6528 Thunderbird Dr   37209.0
# 4                                          604 croley dr   37209.0
# 8                          4484 Lavergne Couchville Pike   37013.0
# 10                                   3113 HYDES FERRY RD   37218.0
# ...                                                  ...       ...
# 20220  2709 Crestdale Dr, Nashville, TN 37214, United...   37214.0
# 20221                             2731 Murfreesboro Pike   37013.0
# 20223  2943 Windemere Cir, Nashville, TN 37214, Unite...   37214.0
# 20224  3325 Murfreesboro Pike, Nashville, TN 37013, U...   37013.0
# 20225  604 Somerset Ct, Nashville, TN 37217, United S...   37217.0
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y
# 1        RED RIVER        4202               1.0  1.721259e+06  685444.799565
# 2        RED RIVER        4205              20.0  1.707027e+06  659887.471571
# 4        RED RIVER        4203              20.0  1.710186e+06  664205.101066
# 8        RED RIVER        4210              33.0  1.794534e+06  618749.342732
# 10       RED RIVER        4204               2.0  1.721578e+06  676018.399900
# ...            ...         ...               ...           ...            ...
# 20220    RED RIVER        1502              15.0  1.770240e+06  676334.399319
# 20221    RED RIVER        4502              32.0  1.781137e+06  632448.551144
# 20223    RED RIVER        1502              15.0  1.770293e+06  674936.303809
# 20224    RED RIVER        4502              32.0  1.785225e+06  627146.400187
# 20225    RED RIVER        2505              29.0  1.781360e+06  637742.006846
#
# [12841 rows x 11 columns]

# %%
#redmiss = redmiss.dropna(subset=['Incident Address'])
#redmiss

# %%
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].str.split(',').str[0]
redmiss
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 8               25330    11/01/17  Trash - Curbside/Alley Missed Pickup
# 10              25341    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20220          267121    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 1                               curb/trash miss tuesday.
# 2                               curb/trash miss tuesday.
# 4                      missed the even side of the road.
# 8                                                missed.
# 10     missed trash pickup - resident has at curb for...
# ...                                                  ...
# 20220                                             missed
# 20221                          missed...neighbors missed
# 20223                                     missed several
# 20224  caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                     Incident Address  Zip Code Trash Hauler Trash Route  \
# 1              4028 Clarksville Pike   37218.0    RED RIVER        4202
# 2                6528 Thunderbird Dr   37209.0    RED RIVER        4205
# 4                      604 croley dr   37209.0    RED RIVER        4203
# 8      4484 Lavergne Couchville Pike   37013.0    RED RIVER        4210
# 10               3113 HYDES FERRY RD   37218.0    RED RIVER        4204
# ...                              ...       ...          ...         ...
# 20220              2709 Crestdale Dr   37214.0    RED RIVER        1502
# 20221         2731 Murfreesboro Pike   37013.0    RED RIVER        4502
# 20223             2943 Windemere Cir   37214.0    RED RIVER        1502
# 20224         3325 Murfreesboro Pike   37013.0    RED RIVER        4502
# 20225                604 Somerset Ct   37217.0    RED RIVER        2505
#
#        Council District  State Plan X   State Plan Y
# 1                   1.0  1.721259e+06  685444.799565
# 2                  20.0  1.707027e+06  659887.471571
# 4                  20.0  1.710186e+06  664205.101066
# 8                  33.0  1.794534e+06  618749.342732
# 10                  2.0  1.721578e+06  676018.399900
# ...                 ...           ...            ...
# 20220              15.0  1.770240e+06  676334.399319
# 20221              32.0  1.781137e+06  632448.551144
# 20223              15.0  1.770293e+06  674936.303809
# 20224              32.0  1.785225e+06  627146.400187
# 20225              29.0  1.781360e+06  637742.006846
#
# [12841 rows x 11 columns]

# %%
redmiss['Incident Address'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 12841 entries, 1 to 20225
# Series name: Incident Address
# Non-Null Count  Dtype
# --------------  -----
# 12840 non-null  object
# dtypes: object(1)
# memory usage: 200.6+ KB

# %%
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].astype('string')
redmiss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12841 entries, 1 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    12841 non-null  int64
#  1   Date Opened       12841 non-null  object
#  2   Request           12841 non-null  string
#  3   Description       12841 non-null  string
#  4   Incident Address  12840 non-null  object
#  5   Zip Code          12813 non-null  float64
#  6   Trash Hauler      12841 non-null  object
#  7   Trash Route       12839 non-null  object
#  8   Council District  12828 non-null  float64
#  9   State Plan X      12836 non-null  float64
#  10  State Plan Y      12836 non-null  float64
# dtypes: float64(4), int64(1), object(4), string(2)
# memory usage: 1.2+ MB

# %%
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].astype('string').str.lower()

# %%
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].str.replace("United States", "")
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].str.replace("Tennessee", "Tn")
redmiss.loc[:, 'Incident Address'] = redmiss['Incident Address'].str.replace("Tn", "")

# %%
redmiss
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 8               25330    11/01/17  Trash - Curbside/Alley Missed Pickup
# 10              25341    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20220          267121    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 1                               curb/trash miss tuesday.
# 2                               curb/trash miss tuesday.
# 4                      missed the even side of the road.
# 8                                                missed.
# 10     missed trash pickup - resident has at curb for...
# ...                                                  ...
# 20220                                             missed
# 20221                          missed...neighbors missed
# 20223                                     missed several
# 20224  caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                     Incident Address  Zip Code Trash Hauler Trash Route  \
# 1              4028 clarksville pike   37218.0    RED RIVER        4202
# 2                6528 thunderbird dr   37209.0    RED RIVER        4205
# 4                      604 croley dr   37209.0    RED RIVER        4203
# 8      4484 lavergne couchville pike   37013.0    RED RIVER        4210
# 10               3113 hydes ferry rd   37218.0    RED RIVER        4204
# ...                              ...       ...          ...         ...
# 20220              2709 crestdale dr   37214.0    RED RIVER        1502
# 20221         2731 murfreesboro pike   37013.0    RED RIVER        4502
# 20223             2943 windemere cir   37214.0    RED RIVER        1502
# 20224         3325 murfreesboro pike   37013.0    RED RIVER        4502
# 20225                604 somerset ct   37217.0    RED RIVER        2505
#
#        Council District  State Plan X   State Plan Y
# 1                   1.0  1.721259e+06  685444.799565
# 2                  20.0  1.707027e+06  659887.471571
# 4                  20.0  1.710186e+06  664205.101066
# 8                  33.0  1.794534e+06  618749.342732
# 10                  2.0  1.721578e+06  676018.399900
# ...                 ...           ...            ...
# 20220              15.0  1.770240e+06  676334.399319
# 20221              32.0  1.781137e+06  632448.551144
# 20223              15.0  1.770293e+06  674936.303809
# 20224              32.0  1.785225e+06  627146.400187
# 20225              29.0  1.781360e+06  637742.006846
#
# [12841 rows x 11 columns]

# %%
redmiss.shape
# Out:
# (12841, 11)

# %%
redmiss['Incident Address'] = redmiss['Incident Address'].str.upper()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\174807461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redmiss['Incident Address'] = redmiss['Incident Address'].str.upper()

# %%
redproblemhouses = redmiss['Incident Address'].nunique()

# %%
redproblemhouses
# Out:
# 8243

# %%
rednon1missed = redmiss.shape[0] - redproblemhouses
rednon1missed
# Out:
# 4598

# %%
redtotalfines = rednon1missed * 200
print(f"The total amount of damages due to missed pickups by Red River is ${redtotalfines}")
# Out:
# The total amount of damages due to missed pickups by Red River is $919600

# %%
metromiss =  missed_pickups.loc[missed_pickups['Trash Hauler'].str.contains('METRO') == True]
metromiss
# Out:
#        Request Number Date Opened                              Request   \
# 7               25327    11/01/17            Trash Collection Complaint
# 9               25331    11/01/17  Trash - Curbside/Alley Missed Pickup
# 12              25359    11/01/17  Trash - Curbside/Alley Missed Pickup
# 22              25471    11/01/17  Trash - Curbside/Alley Missed Pickup
# 39              25539    11/02/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20212          267023    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20213          267035    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20216          267089    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20219          267119    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 7           trash out on time, miss again tuesday. alley
# 9                      trash missed tuesday again, alley
# 12                missed. does not have access to alley.
# 22     alley trash miss tuesday, also others as well,...
# 39     alley trash miss for wednesday. wants cart emp...
# ...                                                  ...
# 20212  trash/missed thursday {carts sit's on the arch...
# 20213                  constantly missed, please pick up
# 20216             the entire street/missed/curb thursday
# 20219                               church missed as wel
# 20222                                       entire alley
#
#                                         Incident Address  Zip Code  \
# 7                                   1816 Jo Johnston Ave   37203.0
# 9                                        1206 Ireland St   37208.0
# 12                                       830 Meridian St   37207.0
# 22                                     1904 MeHarry Blvd   37208.0
# 39                                       2524 Batavia St   37208.0
# ...                                                  ...       ...
# 20212  1098 12th Ave S, Nashville, TN 37203, United S...   37203.0
# 20213  1400 Dickerson Pike, Nashville, TN 37207, Unit...   37207.0
# 20216  1008 Waverly Ave, Nashville, TN 37203, United ...   37203.0
# 20219  1701 Long Ave, Nashville, TN 37206, United States   37206.0
# 20222  1621 Long Ave, Nashville, TN 37206, United States   37206.0
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y
# 7            METRO        9208              21.0  1.731459e+06  666013.601229
# 9            METRO        9208              19.0  1.733029e+06  668762.640891
# 12           METRO        9207               5.0  1.741745e+06  675328.666057
# 22           METRO        9208              21.0  1.730048e+06  668927.190485
# 39           METRO        9303              21.0  1.727574e+06  666486.401815
# ...            ...         ...               ...           ...            ...
# 20212        METRO        9407              17.0  1.736441e+06  660570.319973
# 20213        METRO        9204               5.0  1.740796e+06  679412.798844
# 20216        METRO        9407              17.0  1.736525e+06  657016.001416
# 20219        METRO        9508               6.0  1.750025e+06  669155.312480
# 20222        METRO        9508               6.0  1.749711e+06  669201.601569
#
# [2978 rows x 11 columns]

# %%
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].str.split(',').str[0]
metromiss
# Out:
#        Request Number Date Opened                              Request   \
# 7               25327    11/01/17            Trash Collection Complaint
# 9               25331    11/01/17  Trash - Curbside/Alley Missed Pickup
# 12              25359    11/01/17  Trash - Curbside/Alley Missed Pickup
# 22              25471    11/01/17  Trash - Curbside/Alley Missed Pickup
# 39              25539    11/02/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20212          267023    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20213          267035    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20216          267089    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20219          267119    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 7           trash out on time, miss again tuesday. alley
# 9                      trash missed tuesday again, alley
# 12                missed. does not have access to alley.
# 22     alley trash miss tuesday, also others as well,...
# 39     alley trash miss for wednesday. wants cart emp...
# ...                                                  ...
# 20212  trash/missed thursday {carts sit's on the arch...
# 20213                  constantly missed, please pick up
# 20216             the entire street/missed/curb thursday
# 20219                               church missed as wel
# 20222                                       entire alley
#
#            Incident Address  Zip Code Trash Hauler Trash Route  \
# 7      1816 Jo Johnston Ave   37203.0        METRO        9208
# 9           1206 Ireland St   37208.0        METRO        9208
# 12          830 Meridian St   37207.0        METRO        9207
# 22        1904 MeHarry Blvd   37208.0        METRO        9208
# 39          2524 Batavia St   37208.0        METRO        9303
# ...                     ...       ...          ...         ...
# 20212       1098 12th Ave S   37203.0        METRO        9407
# 20213   1400 Dickerson Pike   37207.0        METRO        9204
# 20216      1008 Waverly Ave   37203.0        METRO        9407
# 20219         1701 Long Ave   37206.0        METRO        9508
# 20222         1621 Long Ave   37206.0        METRO        9508
#
#        Council District  State Plan X   State Plan Y
# 7                  21.0  1.731459e+06  666013.601229
# 9                  19.0  1.733029e+06  668762.640891
# 12                  5.0  1.741745e+06  675328.666057
# 22                 21.0  1.730048e+06  668927.190485
# 39                 21.0  1.727574e+06  666486.401815
# ...                 ...           ...            ...
# 20212              17.0  1.736441e+06  660570.319973
# 20213               5.0  1.740796e+06  679412.798844
# 20216              17.0  1.736525e+06  657016.001416
# 20219               6.0  1.750025e+06  669155.312480
# 20222               6.0  1.749711e+06  669201.601569
#
# [2978 rows x 11 columns]

# %%
metromiss['Incident Address'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2978 entries, 7 to 20222
# Series name: Incident Address
# Non-Null Count  Dtype
# --------------  -----
# 2977 non-null   object
# dtypes: object(1)
# memory usage: 46.5+ KB

# %%
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].astype('string')
metromiss['Incident Address'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2978 entries, 7 to 20222
# Series name: Incident Address
# Non-Null Count  Dtype
# --------------  -----
# 2977 non-null   object
# dtypes: object(1)
# memory usage: 46.5+ KB

# %%
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].astype('string').str.lower()

# %%
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].str.replace("United States", "")
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].str.replace("Tennessee", "Tn")
metromiss.loc[:, 'Incident Address'] = metromiss['Incident Address'].str.replace("Tn", "")

# %%
metromiss['Incident Address'] = metromiss['Incident Address'].str.upper()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\1078073622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metromiss['Incident Address'] = metromiss['Incident Address'].str.upper()

# %%
metroproblemhouses = metromiss['Incident Address'].nunique()

# %%
metronon1missed = metromiss.shape[0] - metroproblemhouses
metronon1missed
# Out:
# 1062

# %%
metrototalfines = metronon1missed * 200
print(f"The total amount of damages due to missed pickups by Red River is ${metrototalfines}")
# Out:
# The total amount of damages due to missed pickups by Red River is $212400

# %%
#compare metrototalfines to redtotalfines

# %%
metromiss['Date Opened'] = pd.to_datetime(metromiss['Date Opened'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\2341449664.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   metromiss['Date Opened'] = pd.to_datetime(metromiss['Date Opened'])
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\2341449664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metromiss['Date Opened'] = pd.to_datetime(metromiss['Date Opened'])

# %%
metromiss['Date Opened'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2978 entries, 7 to 20222
# Series name: Date Opened
# Non-Null Count  Dtype
# --------------  -----
# 2978 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 46.5 KB

# %%
metromiss = metromiss.sort_values(by='Date Opened')

# %%
metromiss_year = metromiss['Date Opened'].value_counts().to_frame().reset_index()
metromiss_year.sort_values('Date Opened').plot(x='Date Opened',y='count')
# Out:
# <Axes: xlabel='Date Opened'>

# %%
redmiss['Date Opened'] = pd.to_datetime(redmiss['Date Opened'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\3994026129.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   redmiss['Date Opened'] = pd.to_datetime(redmiss['Date Opened'])
# C:\Users\user\AppData\Local\Temp\ipykernel_11192\3994026129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redmiss['Date Opened'] = pd.to_datetime(redmiss['Date Opened'])

# %%
redmiss_year = redmiss['Date Opened'].value_counts().to_frame().reset_index()
redmiss_year.sort_values('Date Opened').plot(x='Date Opened',y='count')
# Out:
# <Axes: xlabel='Date Opened'>

# %%
#make these charts bigger

# %%
#go to seaborn wiki to make a fancy chart
