# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
trash = pd.read_csv('../data/trash_hauler_report.csv')

# %%
trash.head(40)
# Out:
#     Request Number Date Opened                              Request   \
# 0            25270    11/01/17                      Trash - Backdoor
# 1            25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2            25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3            25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4            25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 5            25317    11/01/17            Trash Collection Complaint
# 6            25325    11/01/17                    Damage to Property
# 7            25327    11/01/17            Trash Collection Complaint
# 8            25330    11/01/17  Trash - Curbside/Alley Missed Pickup
# 9            25331    11/01/17  Trash - Curbside/Alley Missed Pickup
# 10           25341    11/01/17  Trash - Curbside/Alley Missed Pickup
# 11           25350    11/01/17            Trash Collection Complaint
# 12           25359    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...

# %%
trash['Request ']
# Out:
# 0                            Trash - Backdoor
# 1        Trash - Curbside/Alley Missed Pickup
# 2        Trash - Curbside/Alley Missed Pickup
# 3        Trash - Curbside/Alley Missed Pickup
# 4        Trash - Curbside/Alley Missed Pickup
#                          ...
# 20221    Trash - Curbside/Alley Missed Pickup
# 20222    Trash - Curbside/Alley Missed Pickup
# 20223    Trash - Curbside/Alley Missed Pickup
# 20224    Trash - Curbside/Alley Missed Pickup
# 20225    Trash - Curbside/Alley Missed Pickup
# Name: Request , Length: 20226, dtype: object

# %%
# trashn = trash.loc[trash["Request "].isnull() == False]
trash['Request '].isnull().sum()
trash['Description'].isnull().sum()
# Out:
# 31

# %%
trash['Request '] = trash['Request '].astype('string')
trash['Description'] = trash['Description'].astype('string')
trash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  string
#  3   Description       20195 non-null  string
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
# dtypes: float64(4), int64(1), object(4), string(2)
# memory usage: 1.7+ MB

# %%
trash['Description'] = trash['Description'].fillna("").str.lower().astype('string')
# for Description in trash:
#     if re.findall(r"miss\w?", Description):
#         trash = trash['Description']

# trash.head(40)

# %%
# trashp = trash.loc[trash['Description'].str.contains('miss') == True]
# trashp

# %%
# trashm = trash.loc[trash['Request '].str.contains("Missed") == True]
trashm = trash.loc[
    (trash['Description'].str.contains('miss') == True) |
    (trash['Request '].str.contains('Missed') == True)]
trashm
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 7               25327    11/01/17            Trash Collection Complaint
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trashl = trashm.loc[trashm['Trash Hauler'].str.contains("RED RIVER") == True]
trashl
# Out:
#        Request Number Date Opened                              Request   \
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# 8               25330    11/01/17  Trash - Curbside/Alley Missed Pickup
# 10              25341    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20220          267121    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trashl['Incident Address'].nunique()
# Out:
# 9227

# %%
trashl.value_counts('Incident Address')
# Out:
# Incident Address
# 12546 Old Hickory Blvd, Nashville, TN 37013, United States    19
# 5135 Hickory Hollow Pkwy                                      18
# 6007 Obrien Ave, Nashville, TN 37209, United States           18
# 802 Crescent Rd, Nashville, TN 37205, United States           17
# 3710 N NATCHEZ CT                                             17
#                                                               ..
# 2909 Jones Ave, Nashville, TN 37207, United States             1
# 2909 Elm Hill Pike, Nashville, TN 37214, United States         1
# 2908 Tyne Blvd, Nashville, TN 37215, United States             1
# 2908 Mashburn Rd, Nashville, TN 37211, United States           1
# fransworth dr                                                  1
# Name: count, Length: 9227, dtype: int64

# %%
trash.loc[:, 'Incident Address'] = trashl['Incident Address'].astype('string')
trashl.loc[:, 'Incident Address'] = trashl['Incident Address'].str.lower().str.title()
# trashl.loc[trashl['Incident Address'].str.contains('607 Estes Rd')]

# %%
trashl.loc[:, 'Incident Address'] = trashl['Incident Address'].str.replace("United States", "")
trashl.loc[:, 'Incident Address'] = trashl['Incident Address'].str.replace("Tennessee", "Tn")
trashl.loc[:, 'Incident Address'] = trashl['Incident Address'].str.replace("Tn", "")
# trashl['Incident Address'] = trashl['Incident Address'].str.replace(",", "")
trashl['Incident Address'].nunique()
# Out:
# 9052

# %%
trashl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12841 entries, 1 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    12841 non-null  int64
#  1   Date Opened       12841 non-null  object
#  2   Request           12841 non-null  string
#  3   Description       12841 non-null  string
#  4   Incident Address  12840 non-null  object
#  5   Zip Code          12813 non-null  float64
#  6   Trash Hauler      12841 non-null  object
#  7   Trash Route       12839 non-null  object
#  8   Council District  12828 non-null  float64
#  9   State Plan X      12836 non-null  float64
#  10  State Plan Y      12836 non-null  float64
# dtypes: float64(4), int64(1), object(4), string(2)
# memory usage: 1.7+ MB

# %%
trashl.loc[:, 'Incident Address'] = trashl['Incident Address'].str.rsplit(',').str[0]

trashl['Incident Address'].nunique()
# trashl['Incident Address'].re.search(r',\sTn\d{5},?')
# Out:
# 8243

# %%
un = print(trashl['Incident Address'].unique())
# Out:
# ['4028 Clarksville Pike' '6528 Thunderbird Dr' '604 Croley Dr' ...
#  '3945 Stewarts Ln' '2709 Crestdale Dr' '604 Somerset Ct']

# %%
nonun = trashl.shape
nonun1 = str(nonun)

# %%
type(nonun1)
print(nonun1)
# Out:
# (12841, 11)

# %%
nonun2 = print(nonun1[1:5])
# Out:
# 1284

# %%
nonun3 = str(nonun2)
un2 = str(un)
type(nonun3)
type(un2)
# Out:
# str

# %%
(12841 - 8244) * 200
# Out:
# 919400
